# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True)

# Load and validate Azure AI Services configs
AZURE_AI_SERVICES_ENDPOINT = os.getenv("AZURE_AI_SERVICES_ENDPOINT")
AZURE_AI_SERVICES_API_VERSION = os.getenv("AZURE_AI_SERVICES_API_VERSION")
AZURE_AI_SERVICES_API_KEY = os.getenv("AZURE_AI_SERVICES_API_KEY", None)
assert AZURE_AI_SERVICES_ENDPOINT, "AZURE_AI_SERVICES_ENDPOINT must be set"
assert AZURE_AI_SERVICES_API_VERSION, "AZURE_AI_SERVICES_API_VERSION must be set"

# %% [markdown]
# Create custom analyzer using agreement schemas

# %%
import json
import sys
from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from pathlib import Path

# Get the path to the file that will be analyzed
# Sample report source: https://www.imf.org/en/Publications/CR/Issues/2024/07/18/United-States-2024-Article-IV-Consultation-Press-Release-Staff-Report-and-Statement-by-the-552100
file = Path("./data/ISDA-2.pdf")


# Add the parent directory to the path to use shared modules
parent_dir = Path(Path.cwd()).parent
sys.path.append(
    str(parent_dir)
)
from utility.content_understanding_client import AzureContentUnderstandingClient

# Get token provider once since it will be used for several resources. If you prefer to only use API keys, you can comment out this line.
token_provider = get_bearer_token_provider(DefaultAzureCredential(), "https://cognitiveservices.azure.com/.default")

# Get path to sample template
parent_dir = Path.cwd()  # Now points to the current directory
ANALYZER_TEMPLATE_PATH = "analyzer_templates/isda_extraction.json"
path_to_sample_template = os.path.abspath(
    os.path.join(
        parent_dir,
        ANALYZER_TEMPLATE_PATH,
    )
)
print(path_to_sample_template)

# Create analyzer
ANALYZER_ID = "isda_agreement"
if AZURE_AI_SERVICES_API_KEY:
    content_understanding_client = AzureContentUnderstandingClient(
        endpoint=AZURE_AI_SERVICES_ENDPOINT,
        api_version=AZURE_AI_SERVICES_API_VERSION,
        subscription_key=AZURE_AI_SERVICES_API_KEY
    )
else:
    content_understanding_client = AzureContentUnderstandingClient(
        endpoint=AZURE_AI_SERVICES_ENDPOINT,
        api_version=AZURE_AI_SERVICES_API_VERSION,
        api_token=token_provider()
    )
try:
    response = content_understanding_client.begin_create_analyzer(ANALYZER_ID, analyzer_schema_path=path_to_sample_template)
    result = content_understanding_client.poll_result(response)
    if result is not None and "status" in result and result["status"] == "Succeeded":
        print(f'Analyzer details for {result["result"]["analyzerId"]}:')
        print(json.dumps(result, indent=2))
except Exception as e:
    print(e)
    print("Error in creating analyzer. Please double-check your analysis settings.\nIf there is a conflict, you can delete the analyzer and then recreate it, or move to the next cell and use the existing analyzer.")
# Out:
# /Users/danilodiaz/Source/DocExtraction-CU/analyzer_templates/isda_extraction.json
# Analyzer details for isda_agreement:
# {
#   "id": "209a50b5-a734-48a7-8edb-8123da7637e5",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "isda_agreement",
#     "description": "Extract parties and collateral information from ISDA agreement",
#     "createdAt": "2025-02-14T00:48:24Z",
#     "lastModifiedAt": "2025-02-14T00:48:29Z",
#     "config": {
#       "returnDetails": false,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableBarcode": false,
#       "enableFormula": false,
#       "disableContentFiltering": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "PartyA": {
#           "type": "string",
#           "method": "extract",
#           "description": "Party A"
#         },
#         "PartyB": {
#           "type": "string",
#           "method": "extract",
#           "description": "Party A"
#         },
#         "Collateral": {
#           "type": "array",
#           "method": "extract",
#           "description": "This collateral table might span multiple pages, wrap everything under eligible collateral section",
#           "items": {
#             "type": "object",
#             "properties": {
#               "AssetType": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "This is the first column in the table. It often does not have a column name."
#               },
#               "ValuationPercentage": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "Valuation Percentage column"
#               },
#               "MinimumMaturity": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "Extract the text describing the Minimum tenure maturity years, so if it says LESS than one year, the result would be one year. if it says more than ten years, the min would be ten years. otherwise, if it says not more than put 0. it is always part of the asset type text, not its own column if the asset type is cash it is N/A"
#               },
#               "MaximumMaturity": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "Extract the text describing the Maximum tenure maturity years, so if it says one year or more but less than five, the max would be five year. otherwise put N/A. it is always part of the asset type text, not its own column"
#               }
#             }
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "scenario": "document"
#   }
# }

# %%
content_understanding_response = content_understanding_client.begin_analyze(ANALYZER_ID, file)
content_understanding_result = content_understanding_client.poll_result(content_understanding_response, timeout_seconds=1000)

print(json.dumps(content_understanding_result, indent=2))
# Out:
# {
#   "id": "a9be8da9-e194-48ad-b016-74f093484afe",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "isda_agreement",
#     "apiVersion": "2024-12-01-preview",
#     "createdAt": "2025-02-14T00:48:41Z",
#     "warnings": [],
#     "contents": [
#       {
#         "markdown": "<!-- PageHeader=\"2/11/25, 5:14 PM\" -->\n<!-- PageHeader=\"Credit Support Annex\" -->\n<!-- PageHeader=\"EX-10.11 13 a8821_ex10-11.htm CREDIT SUPPORT ANNEX\" -->\n\n\n# (Bilateral Form)\n\nExhibit 10.11\n(ISDA Agreements Subject to New York Law Only)\n\nISDA\u00ae\n\nInternational Swaps and Derivatives Association, Inc.\n\nCREDIT SUPPORT ANNEX\nto the Schedule to the\n\n\n## ISDA MASTER AGREEMENT dated as of November 16, 2004 between\n\n\n### WACHOVIA BANK, NATIONAL ASSOCIATION (\"Party A\") and\n\n\n#### GOLD BANK (\"Party B\")\n\nThis Annex supplements, forms part of, and is subject to, the ISDA Master Agreement referred to above (this\n\"Agreement\"), is part of its Schedule and is a Credit Support Document under this Agreement with respect to\neach party.\n\nAccordingly, the parties agree as follows: -\n\n\n##### Paragraphs 1 - 12. Incorporation\n\nParagraphs 1 through 12 inclusive of the ISDA Credit Support Annex (Bilateral Form) (ISDA Agreements\nSubject to New York Law Only) published in 1994 by the International Swaps and Derivatives Association, Inc.\nare incorporated herein by reference and made a part hereof.\n\n\n##### Paragraph 13. Elections and Variables\n\n(a) Security Interest for \"Obligations.\" The term \"Obligations\" as used in this Annex includes no additional\nobligations with respect to Party A and Party B.\n\n(b)\nCredit Support Obligations.\n\n(i)\nDelivery Amount, Return Amount and Credit Support Amount.\n\n(A) \"Delivery Amount\" has the meaning specified in Paragraph 3(a).\n\n<!-- PageFooter=\"https://www.sec.gov/Archives/edgar/data/1015610/000108935505000024/a8821_ex10-11.htm\" -->\n<!-- PageNumber=\"1/9\" -->\n<!-- PageBreak -->\n\n2/11/25, 5:14 PM\n\n\n# Credit Support Annex\n\n(B) \"Return Amount\" has the meaning specified in Paragraph 3(b).\n\n(C) \"Credit Support Amount\" has the meaning specified in Paragraph 3.\n\n(ii) Eligible Collateral. The following items will qualify as \"Eligible Collateral\" for the party specified,\nprovided that the Secured Party shall be entitled at any time, and from time to time, not to accept as\nEligible Collateral any of the following which constitute Ineligible Securities as defined below:\n\n\n<table>\n<tr>\n<th></th>\n<th></th>\n<th>Party A</th>\n<th>Party B</th>\n<th>Valuation Percentage</th>\n</tr>\n<tr>\n<td>(A)</td>\n<td>Cash: U.S. Dollars in depositary account form.</td>\n<td>YES</td>\n<td>YES</td>\n<td>100%</td>\n</tr>\n<tr>\n<td>(B)</td>\n<td>Treasury Bills: negotiable obligations issued by the U.S. Treasury Department having a remaining maturity of not more than one year.</td>\n<td>YES</td>\n<td>YES</td>\n<td>98%</td>\n</tr>\n<tr>\n<td>(C)</td>\n<td>Treasury Notes: negotiable debt obligations issued by the U.S. Treasury Department having a remaining maturity of more than one year but not more than 10 years.</td>\n<td>YES</td>\n<td>YES</td>\n<td>98%</td>\n</tr>\n<tr>\n<td>(D)</td>\n<td>Treasury Bonds: negotiable debt obligations issued by the U.S. Treasury Department having a remaining maturity of more than 10 years but not more than 30 years.</td>\n<td>YES</td>\n<td>YES</td>\n<td>92%</td>\n</tr>\n<tr>\n<td>(E)</td>\n<td>Agency Securities: negotiable debt obligations of the Federal National Mortgage Association (FNMA), Federal Home Loan Mortgage Corporation (FHLMC), Federal Home Loan Banks (FHLB), Federal Farm Credit Banks (FFCB), Student Loan Marketing Association (SLMA), Tennessee Valley Authority (TVA) having a remaining maturity of not more than 30 years.</td>\n<td>YES</td>\n<td>YES</td>\n<td>92%</td>\n</tr>\n<tr>\n<td>(F)</td>\n<td>FHLMC Certificates. Mortgage participation certificates issued by FHLMC evidencing undivided interests or participations in pools of first lien conventional or FHA/VA residential mortgages or deeds of trust, guaranteed by FHLMC, and having a remaining maturity of not more than 30 years.</td>\n<td>YES</td>\n<td>YES</td>\n<td>92%</td>\n</tr>\n</table>\n\n\n<!-- PageNumber=\"2\" -->\n<!-- PageFoot ...
#         "fields": {
#           "PartyA": {
#             "type": "string",
#             "valueString": "WACHOVIA BANK, NATIONAL ASSOCIATION",
#             "spans": [
#               {
#                 "offset": 17567,
#                 "length": 35
#               }
#             ],
#             "confidence": 0.945,
#             "source": "D(9,0.4757,0.921,4.1061,0.921,4.1061,1.0961,0.4757,1.0961)"
#           },
#           "PartyB": {
#             "type": "string",
#             "valueString": "GOLD BANK",
#             "spans": [
#               {
#                 "offset": 17690,
#                 "length": 9
#               }
#             ],
#             "confidence": 0.998,
#             "source": "D(9,0.472,2.1917,1.5052,2.1917,1.5052,2.3558,0.472,2.3558)"
#           },
#           "Collateral": {
#             "type": "array",
#             "valueArray": [
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "AssetType": {
#                     "type": "string",
#                     "valueString": "Cash: U.S. Dollars in depositary account form.",
#                     "spans": [
#                       {
#                         "offset": 2225,
#                         "length": 46
#                       }
#                     ],
#                     "confidence": 0.164,
#                     "source": "D(2,1.2397,2.6463,4.3773,2.6463,4.3773,2.84,1.2397,2.84)"
#                   },
#                   "ValuationPercentage": {
#                     "type": "string",
#                     "valueString": "100%",
#                     "spans": [
#                       {
#                         "offset": 2307,
#                         "length": 4
#                       }
#                     ],
#                     "confidence": 0.284,
#                     "source": "D(2,7.2684,2.6486,7.6644,2.6486,7.6644,2.8164,7.2684,2.8164)"
#                   },
#                   "MinimumMaturity": {
#                     "type": "string",
#                     "valueString": "N/A",
#                     "confidence": 0.163
#                   },
#                   "MaximumMaturity": {
#                     "type": "string",
#                     "valueString": "N/A",
#                     "confidence": 0.164
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "AssetType": {
#                     "type": "string",
#                     "valueString": "Treasury Bills: negotiable obligations issued by the U.S. Treasury Department having a remaining maturity of not more than one year.",
#                     "spans": [
#                       {
#                         "offset": 2345,
#                         "length": 57
#                       },
#                       {
#                         "offset": 2403,
#                         "length": 54
#                       },
#                       {
#                         "offset": 2458,
#                         "length": 19
#                       }
#                     ],
#                     "confidence": 0.117,
#                     "source": "D(2,1.2208,3.0197,5.3844,3.0197,5.3844,3.2202,1.2208,3.2202);D(2,1.2198,3.2125,5.401,3.2125,5.401,3.4102,1.2198,3.4102);D(2,1.2163,3.4099,2.5511,3.4099,2.5511,3.5873,1.2163,3.5873)"
#                   },
#                   "ValuationPercentage": {
#                     "type": "string",
#                     "valueString": "98%",
#                     "spans": [
#                       {
#                         "offset": 2513,
#                         "length": 3
#                       }
#                     ],
#                     "confidence": 0.175,
#                     "source": "D(2,7.3197,3.0244,7.6423,3.0244,7.6423,3.1936,7.3197,3.1936)"
#                   },
#                   "MinimumMaturity": {
#                     "type": "string",
#                     "valueString": "0",
#                     "spans": [
#                       {
#                         "offset": 6639,
#                         "length": 1
#                       }
#                     ],
#                     "confidence": 0,
#                     "source": "D(4,1.6531,1.7206,1.7487,1.7206,1.7487,1.88,1.6531,1.88)"
#                   },
#                   "MaximumMaturity": {
#                     "type": "string",
#                     "valueString": "one year",
#                     "spans": [
#                       {
#                         "offset": 2674,
#                         "length": 8
#                       }
#                     ],
#                     "confidence": 0.022,
#                     "source": "D(2,1.9448,4.1542,2.5163,4.1542,2.5163,4.3376,1.9448,4.3376)"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "AssetType": {
#                     "type": "string",
#                     "valueString": "Treasury Notes: negotiable debt obligations issued by the U.S. Treasury Department having a remaining maturity of more than one year but not more than 10 years.",
#                     "spans": [
#                       {
#                         "offset": 2550,
#                         "length": 57
#                       },
#                       {
#                         "offset": 2608,
#                         "length": 55
#                       },
#                       {
#                         "offset": 2664,
#                         "length": 46
#                       }
#                     ],
#                     "confidence": 0.394,
#                     "source": "D(2,1.2208,3.7658,5.3955,3.7658,5.3955,3.9638,1.2208,3.9638);D(2,1.2212,3.9552,5.4121,3.9552,5.4121,4.1575,1.2212,4.1575);D(2,1.2164,4.1541,4.3828,4.1541,4.3828,4.3378,1.2164,4.3378)"
#                   },
#                   "ValuationPercentage": {
#                     "type": "string",
#                     "valueString": "98%",
#                     "spans": [
#                       {
#                         "offset": 2746,
#                         "length": 3
#                       }
#                     ],
#                     "confidence": 0.863,
#                     "source": "D(2,7.3193,3.7693,7.6423,3.7693,7.6423,3.9361,7.3193,3.9361)"
#                   },
#                   "MinimumMaturity": {
#                     "type": "string",
#                     "valueString": "one year",
#                     "spans": [
#                       {
#                         "offset": 2674,
#                         "length": 8
#                       }
#                     ],
#                     "confidence": 0.219,
#                     "source": "D(2,1.9448,4.1542,2.5163,4.1542,2.5163,4.3376,1.9448,4.3376)"
#                   },
#                   "MaximumMaturity": {
#                     "type": "string",
#                     "valueString": "10 years.",
#                     "spans": [
#                       {
#                         "offset": 2701,
#                         "length": 9
#                       }
#                     ],
#                     "confidence": 0.155,
#                     "source": "D(2,3.7952,4.1556,4.3828,4.1556,4.3828,4.3368,3.7952,4.3368)"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "AssetType": {
#                     "type": "string",
#                     "valueString": "Treasury Bonds: negotiable debt obligations issued by the U.S. Treasury Department having a remaining maturity of more than 10 years but not more than 30 years.",
#                     "spans": [
#                       {
#                         "offset": 2783,
#                         "length": 57
#                       },
#                       {
#                         "offset": 2841,
#                         "length": 55
#                       },
#                       {
#                         "offset": 2897,
#                         "length": 46
#                       }
#                     ],
#                     "confidence": 0.288,
#                     "source": "D(2,1.2189,4.5222,5.3955,4.5222,5.3955,4.7167,1.2189,4.7167);D(2,1.2211,4.7089,5.4121,4.7089,5.4121,4.9104,1.2211,4.9104);D(2,1.2162,4.9056,4.3773,4.9056,4.3773,5.0914,1.2162,5.0914)"
#                   },
#                   "ValuationPercentage": {
#                     "type": "string",
#                     "valueString": "92%",
#                     "spans": [
#                       {
#                         "offset": 2979,
#                         "length": 3
#                       }
#                     ],
#                     "confidence": 0.89,
#                     "source": "D(2,7.32,4.5261,7.6423,4.5261,7.6423,4.694,7.32,4.694)"
#                   },
#                   "MinimumMaturity": {
#                     "type": "string",
#                     "valueString": "10 years",
#                     "spans": [
#                       {
#                         "offset": 2907,
#                         "length": 8
#                       }
#                     ],
#                     "confidence": 0.303,
#                     "source": "D(2,1.9632,4.9056,2.5014,4.9056,2.5014,5.09,1.9632,5.09)"
#                   },
#                   "MaximumMaturity": {
#                     "type": "string",
#                     "valueString": "30 years.",
#                     "spans": [
#                       {
#                         "offset": 2934,
#                         "length": 9
#                       }
#                     ],
#                     "confidence": 0.367,
#                     "source": "D(2,3.7706,4.9091,4.3773,4.9091,4.3773,5.0914,3.7706,5.0914)"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "AssetType": {
#                     "type": "string",
#                     "valueString": "Agency Securities: negotiable debt obligations of the Federal National Mortgage Association (FNMA), Federal Home Loan Mortgage Corporation (FHLMC), Federal Home Loan Banks (FHLB), Federal Farm Credit Banks (FFCB), Student Loan Marketing Association (SLMA), Tennessee Valley Authority (TVA) having a remaining maturity of not more than 30 years.",
#                     "spans": [
#                       {
#                         "offset": 3016,
#                         "length": 61
#                       },
#                       {
#                         "offset": 3078,
#                         "length": 55
#                       },
#                       {
#                         "offset": 3134,
#                         "length": 53
#                       },
#                       {
#                         "offset": 3188,
#                         "length": 54
#                       },
#                       {
#                         "offset": 3243,
#                         "length": 56
#                       },
#                       {
#                         "offset": 3300,
#                         "length": 53
#                       },
#                       {
#                         "offset": 3354,
#                         "length": 6
#                       }
#                     ],
#                     "confidence": 0.043,
#                     "source": "D(2,1.2067,5.2653,5.3955,5.2653,5.3955,5.4734,1.2067,5.4734);D(2,1.2153,5.4578,5.401,5.4578,5.401,5.6508,1.2153,5.6508);D(2,1.2152,5.6444,5.3955,5.6444,5.3955,5.8405,1.2152,5.8405);D(2,1.2248,5.8315,5.401,5.8315,5.401,6.0272,1.2248,6.0272);D(2,1.2179,6.0236,5.3955,6.0236,5.3955,6.2224,1.2179,6.2224);D(2,1.2248,6.2076,5.3955,6.2076,5.3955,6.4146,1.2248,6.4146);D(2,1.2166,6.4352,1.6325,6.4352,1.6325,6.5878,1.2166,6.5878)"
#                   },
#                   "ValuationPercentage": {
#                     "type": "string",
#                     "valueString": "92%",
#                     "spans": [
#                       {
#                         "offset": 3396,
#                         "length": 3
#                       }
#                     ],
#                     "confidence": 0.208,
#                     "source": "D(2,7.321,5.2742,7.6423,5.2742,7.6423,5.4405,7.321,5.4405)"
#                   },
#                   "MinimumMaturity": {
#                     "type": "string",
#                     "valueString": "0",
#                     "spans": [
#                       {
#                         "offset": 6639,
#                         "length": 1
#                       }
#                     ],
#                     "confidence": 0.039,
#                     "source": "D(4,1.6531,1.7206,1.7487,1.7206,1.7487,1.88,1.6531,1.88)"
#                   },
#                   "MaximumMaturity": {
#                     "type": "string",
#                     "valueString": "30 years.",
#                     "spans": [
#                       {
#                         "offset": 4696,
#                         "length": 9
#                       }
#                     ],
#                     "confidence": 0.286,
#                     "source": "D(3,2.9907,2.8451,3.5859,2.8451,3.5859,3.0282,2.9907,3.0282)"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "AssetType": {
#                     "type": "string",
#                     "valueString": "FHLMC Certificates. Mortgage participation certificates issued by FHLMC evidencing undivided interests or participations in pools of first lien conventional or FHA/VA residential mortgages or deeds of trust, guaranteed by FHLMC, and having a remaining maturity of not more than 30 years.",
#                     "spans": [
#                       {
#                         "offset": 3433,
#                         "length": 55
#                       },
#                       {
#                         "offset": 3489,
#                         "length": 49
#                       },
#                       {
#                         "offset": 3539,
#                         "length": 60
#                       },
#                       {
#                         "offset": 3600,
#                         "length": 54
#                       },
#                       {
#                         "offset": 3655,
#                         "length": 55
#                       },
#                       {
#                         "offset": 3711,
#                         "length": 9
#                       }
#                     ],
#                     "confidence": 0.011,
#                     "source": "D(2,1.2255,6.7729,5.401,6.7729,5.401,6.968,1.2255,6.968);D(2,1.2215,6.9585,5.401,6.9585,5.401,7.1467,1.2215,7.1467);D(2,1.2174,7.1415,5.3948,7.1415,5.3948,7.3463,1.2174,7.3463);D(2,1.2185,7.3364,5.3955,7.3364,5.3955,7.5323,1.2185,7.5323);D(2,1.2169,7.5234,5.401,7.5234,5.401,7.7172,1.2169,7.7172);D(2,1.2204,7.7201,1.8372,7.7201,1.8372,7.9054,1.2204,7.9054)"
#                   },
#                   "ValuationPercentage": {
#                     "type": "string",
#                     "valueString": "92%",
#                     "spans": [
#                       {
#                         "offset": 3756,
#                         "length": 3
#                       }
#                     ],
#                     "confidence": 0.382,
#                     "source": "D(2,7.3214,6.7743,7.6478,6.7743,7.6478,6.9401,7.3214,6.9401)"
#                   },
#                   "MinimumMaturity": {
#                     "type": "string",
#                     "valueString": "0",
#                     "spans": [
#                       {
#                         "offset": 6639,
#                         "length": 1
#                       }
#                     ],
#                     "confidence": 0.043,
#                     "source": "D(4,1.6531,1.7206,1.7487,1.7206,1.7487,1.88,1.6531,1.88)"
#                   },
#                   "MaximumMaturity": {
#                     "type": "string",
#                     "valueString": "30 years.",
#                     "spans": [
#                       {
#                         "offset": 4696,
#                         "length": 9
#                       }
#                     ],
#                     "confidence": 0.334,
#                     "source": "D(3,2.9907,2.8451,3.5859,2.8451,3.5859,3.0282,2.9907,3.0282)"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "AssetType": {
#                     "type": "string",
#                     "valueString": "FNMA Certificates. Mortgage-backed pass-through certificates issued by FNMA evidencing undivided interests in pools of first lien mortgages or deeds of trust on residential properties, guaranteed by FNMA, and having a remaining maturity of not more than 30 years.",
#                     "spans": [
#                       {
#                         "offset": 4059,
#                         "length": 47
#                       },
#                       {
#                         "offset": 4107,
#                         "length": 58
#                       },
#                       {
#                         "offset": 4166,
#                         "length": 65
#                       },
#                       {
#                         "offset": 4232,
#                         "length": 54
#                       },
#                       {
#                         "offset": 4287,
#                         "length": 35
#                       }
#                     ],
#                     "confidence": 0.022,
#                     "source": "D(3,1.226,0.5889,5.4176,0.5889,5.4176,0.7806,1.226,0.7806);D(3,1.2205,0.7797,5.3955,0.7797,5.3955,0.9577,1.2205,0.9577);D(3,1.2182,0.9575,5.401,0.9575,5.401,1.1507,1.2182,1.1507);D(3,1.2158,1.1492,5.401,1.1492,5.401,1.3492,1.2158,1.3492);D(3,1.2147,1.3439,3.5915,1.3439,3.5915,1.5256,1.2147,1.5256)"
#                   },
#                   "ValuationPercentage": {
#                     "type": "string",
#                     "valueString": "92%",
#                     "spans": [
#                       {
#                         "offset": 4715,
#                         "length": 3
#                       }
#                     ],
#                     "confidence": 0.163,
#                     "source": "D(3,7.2992,1.7129,7.6249,1.7129,7.6249,1.8787,7.2992,1.8787)"
#                   },
#                   "MinimumMaturity": {
#                     "type": "string",
#                     "valueString": "0",
#                     "spans": [
#                       {
#                         "offset": 6639,
#                         "length": 1
#                       }
#                     ],
#                     "confidence": 0.043,
#                     "source": "D(4,1.6531,1.7206,1.7487,1.7206,1.7487,1.88,1.6531,1.88)"
#                   },
#                   "MaximumMaturity": {
#                     "type": "string",
#                     "valueString": "30 years.",
#                     "spans": [
#                       {
#                         "offset": 4696,
#                         "length": 9
#                       }
#                     ],
#                     "confidence": 0.286,
#                     "source": "D(3,2.9907,2.8451,3.5859,2.8451,3.5859,3.0282,2.9907,3.0282)"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "AssetType": {
#                     "type": "string",
#                     "valueString": "GNMA Certificates. Mortgage-backed pass-through certificates issued by private entities, evidencing undivided interests in pools of first lien mortgages or deeds of trust on single family residences, guaranteed by the Government National Mortgage Association (GNMA) with the full faith and credit of the United States, and having a remaining maturity of not more than 30 years.",
#                     "spans": [
#                       {
#                         "offset": 4328,
#                         "length": 47
#                       },
#                       {
#                         "offset": 4376,
#                         "length": 61
#                       },
#                       {
#                         "offset": 4438,
#                         "length": 63
#                       },
#                       {
#                         "offset": 4502,
#                         "length": 54
#                       },
#                       {
#                         "offset": 4557,
#                         "length": 56
#                       },
#                       {
#                         "offset": 4614,
#                         "length": 55
#                       },
#                       {
#                         "offset": 4670,
#                         "length": 35
#                       }
#                     ],
#                     "confidence": 0.008,
#                     "source": "D(3,1.2388,1.7094,5.401,1.7094,5.401,1.9044,1.2388,1.9044);D(3,1.2214,1.9001,5.401,1.9001,5.401,2.0871,1.2214,2.0871);D(3,1.2181,2.0938,5.401,2.0938,5.401,2.2753,1.2181,2.2753);D(3,1.2183,2.2777,5.4063,2.2777,5.4063,2.4684,1.2183,2.4684);D(3,1.2153,2.4582,5.3955,2.4582,5.3955,2.6443,1.2153,2.6443);D(3,1.2204,2.6499,5.401,2.6499,5.401,2.8455,1.2204,2.8455);D(3,1.2151,2.8444,3.5859,2.8444,3.5859,3.0282,1.2151,3.0282)"
#                   },
#                   "ValuationPercentage": {
#                     "type": "string",
#                     "valueString": "92%",
#                     "spans": [
#                       {
#                         "offset": 4715,
#                         "length": 3
#                       }
#                     ],
#                     "confidence": 0.18,
#                     "source": "D(3,7.2992,1.7129,7.6249,1.7129,7.6249,1.8787,7.2992,1.8787)"
#                   },
#                   "MinimumMaturity": {
#                     "type": "string",
#                     "valueString": "0",
#                     "spans": [
#                       {
#                         "offset": 6639,
#                         "length": 1
#                       }
#                     ],
#                     "confidence": 0.161,
#                     "source": "D(4,1.6531,1.7206,1.7487,1.7206,1.7487,1.88,1.6531,1.88)"
#                   },
#                   "MaximumMaturity": {
#                     "type": "string",
#                     "valueString": "30 years.",
#                     "spans": [
#                       {
#                         "offset": 4696,
#                         "length": 9
#                       }
#                     ],
#                     "confidence": 0.34,
#                     "source": "D(3,2.9907,2.8451,3.5859,2.8451,3.5859,3.0282,2.9907,3.0282)"
#                   }
#                 }
#               }
#             ]
#           }
#         },
#         "kind": "document",
#         "startPageNumber": 1,
#         "endPageNumber": 9,
#         "unit": "inch",
#         "pages": [
#           {
#             "pageNumber": 1,
#             "angle": -0.0056,
#             "width": 8.5,
#             "height": 11
#           },
#           {
#             "pageNumber": 2,
#             "angle": 0.008473744,
#             "width": 8.5,
#             "height": 11
#           },
#           {
#             "pageNumber": 3,
#             "angle": 0.004024833,
#             "width": 8.5,
#             "height": 11
#           },
#           {
#             "pageNumber": 4,
#             "angle": 0.0001920705,
#             "width": 8.5,
#             "height": 11
#           },
#           {
#             "pageNumber": 5,
#             "angle": 0.0009341066,
#             "width": 8.5,
#             "height": 11
#           },
#           {
#             "pageNumber": 6,
#             "angle": 0.000215659,
#             "width": 8.5,
#             "height": 11
#           },
#           {
#             "pageNumber": 7,
#             "angle": 0.03313895,
#             "width": 8.5,
#             "height": 11
#           },
#           {
#             "pageNumber": 8,
#             "angle": 0.02355869,
#             "width": 8.5,
#             "height": 11
#           },
#           {
#             "pageNumber": 9,
#             "angle": 0.01040963,
#             "width": 8.5,
#             "height": 11
#           }
#         ]
#       }
#     ]
#   }
# }
